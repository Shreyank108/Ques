# %%
import pandas as pd

# %%
data=pd.read_csv("C:\\Users\\ASUS\\Desktop\\out of range\\champions.csv")

# %%
data.head()
# Out:
#   Champion Name     Role  Base Health  Base Mana  Base Armor  \
# 0        Aatrox      Top          580          0          38
# 1          Ahri      Mid          526        418          21
# 2         Akali      Mid          575        200          23
# 3       Alistar  Support          600        350          44
# 4         Amumu   Jungle          615        285          33
#
#    Base Attack Damage  Gold Efficiency
# 0                  60             1.05
# 1                  53             1.02
# 2                  62             1.03
# 3                  62             1.08
# 4                  53             1.06

# %%
data.shape
# Out:
# (149, 7)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149 entries, 0 to 148
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Champion Name       149 non-null    object
#  1   Role                149 non-null    object
#  2   Base Health         149 non-null    int64
#  3   Base Mana           149 non-null    int64
#  4   Base Armor          149 non-null    int64
#  5   Base Attack Damage  149 non-null    int64
#  6   Gold Efficiency     149 non-null    float64
# dtypes: float64(1), int64(4), object(2)
# memory usage: 8.3+ KB

# %%
data.columns
# Out:
# Index(['Champion Name', 'Role', 'Base Health', 'Base Mana', 'Base Armor',
#        'Base Attack Damage', 'Gold Efficiency'],
#       dtype='object')

# %%
FindingName=data[data["Champion Name"].str.startswith('A')]

# %%
FindingName
# Out:
#   Champion Name     Role  Base Health  Base Mana  Base Armor  \
# 0        Aatrox      Top          580          0          38
# 1          Ahri      Mid          526        418          21
# 2         Akali      Mid          575        200          23
# 3       Alistar  Support          600        350          44
# 4         Amumu   Jungle          615        285          33
# 5        Anivia      Mid          480        495          21
# 6         Annie      Mid          524        418          19
# 7          Ashe      ADC          570        280          26
# 8  Aurelion Sol      Mid          575        350          19
# 9          Azir      Mid          552        438          19
#
#    Base Attack Damage  Gold Efficiency
# 0                  60             1.05
# 1                  53             1.02
# 2                  62             1.03
# 3                  62             1.08
# 4                  53             1.06
# 5                  51             1.01
# ...

# %%
data[data['Champion Name']=="Aatrox"]
# Out:
#   Champion Name Role  Base Health  Base Mana  Base Armor  Base Attack Damage  \
# 0        Aatrox  Top          580          0          38                  60
#
#    Gold Efficiency
# 0             1.05

# %%
data.describe()
# Out:
#        Base Health   Base Mana  Base Armor  Base Attack Damage  \
# count   149.000000  149.000000  149.000000          149.000000
# mean    557.241611  313.315436   29.939597           59.476510
# std      36.953340  123.571792    6.801459            5.845516
# min     340.000000    0.000000   17.000000           45.000000
# 25%     532.000000  280.000000   24.000000           55.000000
# 50%     562.000000  325.000000   30.000000           60.000000
# 75%     585.000000  375.000000   35.000000           64.000000
# max     625.000000  800.000000   47.000000           72.000000
#
#        Gold Efficiency
# count       149.000000
# mean          1.042282
# std           0.020438
# min           1.000000
# 25%           1.020000
# 50%           1.040000
# 75%           1.060000
# max           1.100000

# %%
data[["Base Armor","Champion Name"]]
# Out:
#      Base Armor Champion Name
# 0            38        Aatrox
# 1            21          Ahri
# 2            23         Akali
# 3            44       Alistar
# 4            33         Amumu
# ..          ...           ...
# 144          32           Zed
# 145          21         Ziggs
# 146          22        Zilean
# 147          20           Zoe
# 148          29          Zyra
#
# [149 rows x 2 columns]

# %%
data.iloc[0:5]
# Out:
#   Champion Name     Role  Base Health  Base Mana  Base Armor  \
# 0        Aatrox      Top          580          0          38
# 1          Ahri      Mid          526        418          21
# 2         Akali      Mid          575        200          23
# 3       Alistar  Support          600        350          44
# 4         Amumu   Jungle          615        285          33
#
#    Base Attack Damage  Gold Efficiency
# 0                  60             1.05
# 1                  53             1.02
# 2                  62             1.03
# 3                  62             1.08
# 4                  53             1.06

# %%
data[data["Gold Efficiency"] >1.09]
# Out:
#    Champion Name     Role  Base Health  Base Mana  Base Armor  \
# 62         Leona  Support          576        302          47
#
#     Base Attack Damage  Gold Efficiency
# 62                  60              1.1

# %%
condition = (data["Champion Name"] == "Aatrox") & (data["Base Mana"] == 0)

# %%
data.loc[condition,'Base Mana'] =5

# %%
data.head()
# Out:
#   Champion Name     Role  Base Health  Base Mana  Base Armor  \
# 0        Aatrox      Top          580          5          38
# 1          Ahri      Mid          526        418          21
# 2         Akali      Mid          575        200          23
# 3       Alistar  Support          600        350          44
# 4         Amumu   Jungle          615        285          33
#
#    Base Attack Damage  Gold Efficiency
# 0                  60             1.05
# 1                  53             1.02
# 2                  62             1.03
# 3                  62             1.08
# 4                  53             1.06

# %%
# +------------+---------+-----+
# | student_id | name    | age |
# +------------+---------+-----+
# | 101        | Ulysses | 13  |
# | 53         | William | 10  |
# | 128        | Henry   | 6   |
# | 3          | Henry   | 11  |
# +------------+---------+-----+
